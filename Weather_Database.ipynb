# %%
import pandas as pd
import requests
import gmaps
import random
import numpy as np
from citipy import citipy
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(-90.00,90.00,2000)
lngs = np.random.uniform(-180.00,180.00, 2000)
lats_lngs = zip(lats,lngs)
coordinates = list(lats_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 753

# %%
# Check
check_url = url + "&q=Miami"
city_data_check = requests.get(check_url).json()
city_data_check
# Out:
# {'coord': {'lon': -80.1937, 'lat': 25.7743},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 83.77,
#   'feels_like': 89.98,
#   'temp_min': 81.99,
#   'temp_max': 87.03,
#   'pressure': 1015,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 120, 'gust': 23.02},
#  'clouds': {'all': 75},
#  'dt': 1650213626,
#  'sys': {'type': 2,
#   'id': 2009435,
#   'country': 'US',
#   'sunrise': 1650192943,
#   'sunset': 1650239069},
#  'timezone': -14400,
#  'id': 4164138,
#  'name': 'Miami',
#  'cod': 200}

# %% [markdown]
# # Retrieve data

# %%
# Retrieve info from all cities
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print("------------------------------")

# Counters for 50 cities in 10 sets for the 500 total
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descript = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | glenwood springs
# Processing Record 2 of Set 1 | gladstone
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | sola
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | waipawa
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | nyrob
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hervey bay
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | george town
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | springbok
# Processing Record 28 of Set 1 | baykit
# Processing Record 29 of Set 1 | boshnyakovo
# Processing Record 30 of Set 1 | shitanjing
# Processing Record 31 of Set 1 | hobyo
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | wattegama
# Processing Record 38 of Set 1 | borger
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | bathsheba
# Processing Record 44 of Set 1 | fort wellington
# Processing Record 45 of Set 1 | asau
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | katsuura
# Processing Record 50 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | santiago del estero
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | quelimane
# Processing Record 4 of Set 2 | sysert
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | szigetvar
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | daura
# Processing Record 10 of Set 2 | atambua
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | akure
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | aksarka
# Processing Record 16 of Set 2 | kushima
# Processing Record 17 of Set 2 | cortez
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | taguisa
# Processing Record 20 of Set 2 | balgazyn
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | ouesso
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | olopa
# Processing Record 26 of Set 2 | dondo
# Processing Record 27 of Set 2 | jumla
# Processing Record 28 of Set 2 | vostok
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | koungheul
# Processing Record 31 of Set 2 | oranjemund
# Processing Record 32 of Set 2 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | sokolskoye
# Processing Record 37 of Set 2 | port-gentil
# Processing Record 38 of Set 2 | pedernales
# Processing Record 39 of Set 2 | french harbor
# Processing Record 40 of Set 2 | andenes
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | datong
# Processing Record 43 of Set 2 | omsukchan
# Processing Record 44 of Set 2 | sao miguel do araguaia
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | sheridan
# Processing Record 47 of Set 2 | dubovskoye
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | kosino
# Processing Record 50 of Set 2 | sinnamary
# Processing Record 1 of Set 3 | puerto penasco
# Processing Record 2 of Set 3 | slonim
# Processing Record 3 of Set 3 | matadi
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | walvis bay
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | radzyn podlaski
# Processing Record 8 of Set 3 | ballyshannon
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | mwingi
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 3 | pontianak
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | altamont
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | aswan
# Processing Record 20 of Set 3 | sorong
# Processing Record 21 of Set 3 | langsa
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | shubarshi
# Processing Record 24 of Set 3 | mount gambier
# Processing Record 25 of Set 3 | hibbing
# Processing Record 26 of Set 3 | borgo san dalmazzo
# Processing Record 27 of Set 3 | tigil
# Processing Record 28 of Set 3 | zalantun
# Processing Record 29 of Set 3 | bari
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | havelock
# Processing Record 32 of Set 3 | basavana bagevadi
# Processing Record 33 of Set 3 | statesville
# Processing Record 34 of Set 3 | grande-riviere
# City not found. Skipping...
# Processing Record 35 of Set 3 | iberia
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | akureyri
# Processing Record 38 of Set 3 | drovyanaya
# Processing Record 39 of Set 3 | kavieng
# Processing Record 40 of Set 3 | storforshei
# Processing Record 41 of Set 3 | aykhal
# Processing Record 42 of Set 3 | batangafo
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | beyneu
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | tubmanburg
# Processing Record 3 of Set 4 | sur
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | meiganga
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 4 | dubrovnik
# Processing Record 9 of Set 4 | manicore
# Processing Record 10 of Set 4 | tabuk
# Processing Record 11 of Set 4 | grindavik
# Processing Record 12 of Set 4 | vao
# Processing Record 13 of Set 4 | hare bay
# Processing Record 14 of Set 4 | baruun-urt
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | tejupilco
# City not found. Skipping...
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | kuytun
# Processing Record 19 of Set 4 | birin
# Processing Record 20 of Set 4 | nogliki
# Processing Record 21 of Set 4 | raymondville
# Processing Record 22 of Set 4 | jeremoabo
# Processing Record 23 of Set 4 | muros
# Processing Record 24 of Set 4 | havre-saint-pierre
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | hastings
# Processing Record 27 of Set 4 | teahupoo
# Processing Record 28 of Set 4 | helong
# Processing Record 29 of Set 4 | port lincoln
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | fukuma
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | karpathos
# Processing Record 36 of Set 4 | faranah
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | mitu
# Processing Record 39 of Set 4 | mahanoro
# Processing Record 40 of Set 4 | khartoum
# Processing Record 41 of Set 4 | jasper
# Processing Record 42 of Set 4 | palmer
# Processing Record 43 of Set 4 | nuuk
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | dongsheng
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | borsa
# Processing Record 50 of Set 4 | bonfim
# Processing Record 1 of Set 5 | ayorou
# Processing Record 2 of Set 5 | kenai
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | salo
# Processing Record 6 of Set 5 | monte alegre
# Processing Record 7 of Set 5 | adrar
# Processing Record 8 of Set 5 | ixtapa
# Processing Record 9 of Set 5 | bosobolo
# Processing Record 10 of Set 5 | opuwo
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | ostersund
# Processing Record 15 of Set 5 | neiafu
# Processing Record 16 of Set 5 | jalu
# Processing Record 17 of Set 5 | stonewall
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | kerema
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | matara
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | acapulco
# Processing Record 27 of Set 5 | da nang
# Processing Record 28 of Set 5 | lasa
# Processing Record 29 of Set 5 | atuona
# Processing Record 30 of Set 5 | phitsanulok
# Processing Record 31 of Set 5 | barentu
# Processing Record 32 of Set 5 | chara
# Processing Record 33 of Set 5 | antofagasta
# Processing Record 34 of Set 5 | ouadda
# Processing Record 35 of Set 5 | mozarlandia
# Processing Record 36 of Set 5 | nizhniy tsasuchey
# Processing Record 37 of Set 5 | emerald
# Processing Record 38 of Set 5 | kindu
# Processing Record 39 of Set 5 | kassala
# Processing Record 40 of Set 5 | waingapu
# Processing Record 41 of Set 5 | esperance
# Processing Record 42 of Set 5 | helena
# Processing Record 43 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 5 | eskil
# Processing Record 45 of Set 5 | yarim
# Processing Record 46 of Set 5 | half moon bay
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | bethel
# Processing Record 49 of Set 5 | provideniya
# Processing Record 50 of Set 5 | nalut
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | kozhva
# Processing Record 4 of Set 6 | ambilobe
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | saint-leu
# Processing Record 7 of Set 6 | wad rawah
# Processing Record 8 of Set 6 | witu
# Processing Record 9 of Set 6 | saint-philippe
# Processing Record 10 of Set 6 | thompson
# Processing Record 11 of Set 6 | willowmore
# Processing Record 12 of Set 6 | urucara
# Processing Record 13 of Set 6 | petrolina
# Processing Record 14 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 15 of Set 6 | pizarro
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 | geraldton
# Processing Record 18 of Set 6 | komsomolskiy
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | shahpur
# Processing Record 22 of Set 6 | teacapan
# Processing Record 23 of Set 6 | veraval
# Processing Record 24 of Set 6 | zhezkazgan
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | karratha
# Processing Record 28 of Set 6 | marshalltown
# Processing Record 29 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 6 | meulaboh
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | clarence town
# Processing Record 33 of Set 6 | makakilo city
# Processing Record 34 of Set 6 | puerto escondido
# Processing Record 35 of Set 6 | rio gallegos
# Processing Record 36 of Set 6 | pangnirtung
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | umm lajj
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | mahon
# Processing Record 41 of Set 6 | tuatapere
# Processing Record 42 of Set 6 | general cepeda
# Processing Record 43 of Set 6 | porto murtinho
# Processing Record 44 of Set 6 | vanimo
# Processing Record 45 of Set 6 | mayumba
# Processing Record 46 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 6 | diego de almagro
# Processing Record 48 of Set 6 | prince rupert
# Processing Record 49 of Set 6 | isangel
# Processing Record 50 of Set 6 | damara
# Processing Record 1 of Set 7 | los llanos de aridane
# Processing Record 2 of Set 7 | alekseyevsk
# Processing Record 3 of Set 7 | phan thiet
# Processing Record 4 of Set 7 | hendersonville
# Processing Record 5 of Set 7 | san luis
# Processing Record 6 of Set 7 | toora-khem
# Processing Record 7 of Set 7 | naze
# Processing Record 8 of Set 7 | kharp
# Processing Record 9 of Set 7 | point pedro
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | te anau
# Processing Record 12 of Set 7 | trairi
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | ciudad bolivar
# Processing Record 15 of Set 7 | manado
# Processing Record 16 of Set 7 | porto novo
# Processing Record 17 of Set 7 | bokoro
# Processing Record 18 of Set 7 | porto velho
# Processing Record 19 of Set 7 | haikou
# Processing Record 20 of Set 7 | nelson bay
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | chekhov
# Processing Record 23 of Set 7 | gannan
# Processing Record 24 of Set 7 | elmadag
# Processing Record 25 of Set 7 | kahului
# Processing Record 26 of Set 7 | pacifica
# Processing Record 27 of Set 7 | araouane
# Processing Record 28 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 7 | coahuayana
# Processing Record 30 of Set 7 | pesochnoye
# Processing Record 31 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | kytmanovo
# Processing Record 36 of Set 7 | van
# Processing Record 37 of Set 7 | moroni
# Processing Record 38 of Set 7 | jilib
# Processing Record 39 of Set 7 | tezu
# Processing Record 40 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | hoi an
# Processing Record 42 of Set 7 | boa vista
# Processing Record 43 of Set 7 | mozirje
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | kintinku
# Processing Record 46 of Set 7 | namatanai
# Processing Record 47 of Set 7 | broken hill
# Processing Record 48 of Set 7 | magadan
# Processing Record 49 of Set 7 | la cruz
# Processing Record 50 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 1 of Set 8 | lerwick
# Processing Record 2 of Set 8 | gallup
# Processing Record 3 of Set 8 | porkhov
# Processing Record 4 of Set 8 | jaciara
# Processing Record 5 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 6 of Set 8 | arvika
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | kaka
# Processing Record 9 of Set 8 | tena
# Processing Record 10 of Set 8 | xingtai
# Processing Record 11 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 12 of Set 8 | mahishadal
# Processing Record 13 of Set 8 | vicksburg
# Processing Record 14 of Set 8 | turka
# Processing Record 15 of Set 8 | mattru
# Processing Record 16 of Set 8 | talara
# Processing Record 17 of Set 8 | codrington
# Processing Record 18 of Set 8 | warrnambool
# Processing Record 19 of Set 8 | sao felix do xingu
# Processing Record 20 of Set 8 | iquique
# Processing Record 21 of Set 8 | paita
# Processing Record 22 of Set 8 | asosa
# Processing Record 23 of Set 8 | tecoanapa
# Processing Record 24 of Set 8 | okato
# Processing Record 25 of Set 8 | port augusta
# Processing Record 26 of Set 8 | benalla
# Processing Record 27 of Set 8 | puerto del rosario
# Processing Record 28 of Set 8 | moyale
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | havoysund
# Processing Record 31 of Set 8 | pascagoula
# Processing Record 32 of Set 8 | mount isa
# Processing Record 33 of Set 8 | tahe
# Processing Record 34 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 8 | rajura
# Processing Record 36 of Set 8 | sakakah
# Processing Record 37 of Set 8 | ramanuj ganj
# Processing Record 38 of Set 8 | vila
# Processing Record 39 of Set 8 | atar
# Processing Record 40 of Set 8 | agirish
# Processing Record 41 of Set 8 | santa maria
# Processing Record 42 of Set 8 | keetmanshoop
# Processing Record 43 of Set 8 | virginia beach
# Processing Record 44 of Set 8 | arkhangelsk
# Processing Record 45 of Set 8 | college
# Processing Record 46 of Set 8 | balkanabat
# Processing Record 47 of Set 8 | huallanca
# Processing Record 48 of Set 8 | gorin
# Processing Record 49 of Set 8 | hamilton
# Processing Record 50 of Set 8 | dwarka
# Processing Record 1 of Set 9 | atbasar
# Processing Record 2 of Set 9 | suleja
# Processing Record 3 of Set 9 | hailey
# Processing Record 4 of Set 9 | visnes
# Processing Record 5 of Set 9 | mwinilunga
# Processing Record 6 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 9 | saqqez
# Processing Record 8 of Set 9 | weyburn
# Processing Record 9 of Set 9 | dukat
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | katobu
# Processing Record 12 of Set 9 | kroderen
# City not found. Skipping...
# Processing Record 13 of Set 9 | nome
# Processing Record 14 of Set 9 | granby
# Processing Record 15 of Set 9 | buchanan
# Processing Record 16 of Set 9 | requena
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | achacachi
# Processing Record 19 of Set 9 | binga
# Processing Record 20 of Set 9 | natal
# Processing Record 21 of Set 9 | rawson
# Processing Record 22 of Set 9 | nchelenge
# Processing Record 23 of Set 9 | chegdomyn
# Processing Record 24 of Set 9 | odweyne
# Processing Record 25 of Set 9 | tazovskiy
# Processing Record 26 of Set 9 | ergolding
# Processing Record 27 of Set 9 | edd
# Processing Record 28 of Set 9 | maniitsoq
# Processing Record 29 of Set 9 | bulawayo
# Processing Record 30 of Set 9 | daru
# Processing Record 31 of Set 9 | kardamas
# Processing Record 32 of Set 9 | santa fe
# Processing Record 33 of Set 9 | clyde river
# Processing Record 34 of Set 9 | okahandja
# Processing Record 35 of Set 9 | san angelo
# Processing Record 36 of Set 9 | lakes entrance
# Processing Record 37 of Set 9 | noumea
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | daokou
# Processing Record 40 of Set 9 | dauriya
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | kuzovatovo
# Processing Record 43 of Set 9 | swan hill
# Processing Record 44 of Set 9 | brae
# Processing Record 45 of Set 9 | chicama
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | udachnyy
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | hay river
# Processing Record 50 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 10 | polyarnyy
# Processing Record 2 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 3 of Set 10 | pak chong
# Processing Record 4 of Set 10 | jimenez
# Processing Record 5 of Set 10 | tutoia
# Processing Record 6 of Set 10 | eureka
# Processing Record 7 of Set 10 | marawi
# Processing Record 8 of Set 10 | lucapa
# Processing Record 9 of Set 10 | honiara
# Processing Record 10 of Set 10 | mangan
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | san cristobal
# Processing Record 13 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 14 of Set 10 | launceston
# Processing Record 15 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 10 | zhangye
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | narasannapeta
# Processing Record 19 of Set 10 | santo tomas
# Processing Record 20 of Set 10 | basco
# Processing Record 21 of Set 10 | imbituba
# Processing Record 22 of Set 10 | ovalle
# Processing Record 23 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 10 | chitrakonda
# Processing Record 25 of Set 10 | ewa beach
# Processing Record 26 of Set 10 | labuhan
# Processing Record 27 of Set 10 | saint-francois
# Processing Record 28 of Set 10 | zatec
# Processing Record 29 of Set 10 | tautira
# Processing Record 30 of Set 10 | port blair
# Processing Record 31 of Set 10 | nouakchott
# Processing Record 32 of Set 10 | takaka
# Processing Record 33 of Set 10 | abha
# Processing Record 34 of Set 10 | carolina
# Processing Record 35 of Set 10 | padang
# Processing Record 36 of Set 10 | itoman
# Processing Record 37 of Set 10 | birao
# Processing Record 38 of Set 10 | tarangnan
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | auburn
# Processing Record 41 of Set 10 | bageshwar
# Processing Record 42 of Set 10 | tabou
# Processing Record 43 of Set 10 | papayal
# Processing Record 44 of Set 10 | extremoz
# Processing Record 45 of Set 10 | henties bay
# Processing Record 46 of Set 10 | bambanglipuro
# Processing Record 47 of Set 10 | bagdarin
# Processing Record 48 of Set 10 | brunswick
# Processing Record 49 of Set 10 | ketchikan
# Processing Record 50 of Set 10 | pisco
# Processing Record 1 of Set 11 | bontang
# Processing Record 2 of Set 11 | caxito
# Processing Record 3 of Set 11 | blackfoot
# Processing Record 4 of Set 11 | kyra
# Processing Record 5 of Set 11 | morlaix
# Processing Record 6 of Set 11 | corn island
# Processing Record 7 of Set 11 | ryotsu
# Processing Record 8 of Set 11 | matay
# Processing Record 9 of Set 11 | morant bay
# Processing Record 10 of Set 11 | pitimbu
# Processing Record 11 of Set 11 | zeya
# Processing Record 12 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 11 | mayo
# Processing Record 14 of Set 11 | voh
# Processing Record 15 of Set 11 | ilam
# Processing Record 16 of Set 11 | cap malheureux
# Processing Record 17 of Set 11 | minas de barroteran
# Processing Record 18 of Set 11 | lishui
# Processing Record 19 of Set 11 | san luis obispo
# Processing Record 20 of Set 11 | kachug
# Processing Record 21 of Set 11 | high level
# Processing Record 22 of Set 11 | richards bay
# Processing Record 23 of Set 11 | inongo
# Processing Record 24 of Set 11 | maningrida
# Processing Record 25 of Set 11 | kysyl-syr
# Processing Record 26 of Set 11 | olafsvik
# Processing Record 27 of Set 11 | beringovskiy
# Processing Record 28 of Set 11 | ukiah
# Processing Record 29 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 30 of Set 11 | aljezur
# Processing Record 31 of Set 11 | srednekolymsk
# Processing Record 32 of Set 11 | flin flon
# Processing Record 33 of Set 11 | iracoubo
# Processing Record 34 of Set 11 | ilulissat
# Processing Record 35 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 36 of Set 11 | lubyany
# Processing Record 37 of Set 11 | kailua
# Processing Record 38 of Set 11 | magoula
# Processing Record 39 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 11 | querecotillo
# Processing Record 41 of Set 11 | lemon tree passage
# Processing Record 42 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 43 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 44 of Set 11 | qaqortoq
# Processing Record 45 of Set 11 | altay
# Processing Record 46 of Set 11 | rocha
# Processing Record 47 of Set 11 | viedma
# Processing Record 48 of Set 11 | namwala
# Processing Record 49 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 11 | nabire
# Processing Record 1 of Set 12 | chuy
# Processing Record 2 of Set 12 | goleniow
# Processing Record 3 of Set 12 | cherskiy
# Processing Record 4 of Set 12 | axim
# Processing Record 5 of Set 12 | ossora
# Processing Record 6 of Set 12 | cabedelo
# Processing Record 7 of Set 12 | maslovare
# Processing Record 8 of Set 12 | mnogovershinnyy
# Processing Record 9 of Set 12 | acajutla
# Processing Record 10 of Set 12 | joshimath
# Processing Record 11 of Set 12 | husavik
# Processing Record 12 of Set 12 | davila
# Processing Record 13 of Set 12 | kamenka
# Processing Record 14 of Set 12 | dingle
# Processing Record 15 of Set 12 | kulachi
# Processing Record 16 of Set 12 | rabo de peixe
# Processing Record 17 of Set 12 | baoqing
# Processing Record 18 of Set 12 | aklavik
# Processing Record 19 of Set 12 | el alto
# Processing Record 20 of Set 12 | tessalit
# Processing Record 21 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 22 of Set 12 | homer
# Processing Record 23 of Set 12 | takoradi
# Processing Record 24 of Set 12 | khani
# Processing Record 25 of Set 12 | cermik
# Processing Record 26 of Set 12 | yar-sale
# Processing Record 27 of Set 12 | okha
# Processing Record 28 of Set 12 | san policarpo
# Processing Record 29 of Set 12 | leszno
# Processing Record 30 of Set 12 | mecca
# Processing Record 31 of Set 12 | salalah
# Processing Record 32 of Set 12 | santa marta
# Processing Record 33 of Set 12 | leshukonskoye
# Processing Record 34 of Set 12 | san jeronimo
# Processing Record 35 of Set 12 | manlleu
# Processing Record 36 of Set 12 | russell
# Processing Record 37 of Set 12 | orlik
# Processing Record 38 of Set 12 | dulce nombre de culmi
# Processing Record 39 of Set 12 | ritchie
# Processing Record 40 of Set 12 | georgiu-dezh
# City not found. Skipping...
# Processing Record 41 of Set 12 | najran
# Processing Record 42 of Set 12 | sao joao da barra
# Processing Record 43 of Set 12 | kungurtug
# Processing Record 44 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 12 | coari
# Processing Record 46 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 12 | puri
# Processing Record 48 of Set 12 | krasnyy chikoy
# Processing Record 49 of Set 12 | savinka
# Processing Record 50 of Set 12 | anadyr
# Processing Record 1 of Set 13 | pokhara
# Processing Record 2 of Set 13 | caravelas
# Processing Record 3 of Set 13 | alice springs
# Processing Record 4 of Set 13 | aktash
# Processing Record 5 of Set 13 | jitra
# Processing Record 6 of Set 13 | meadow lake
# Processing Record 7 of Set 13 | maraa
# Processing Record 8 of Set 13 | mersing
# Processing Record 9 of Set 13 | elizabeth city
# Processing Record 10 of Set 13 | herat
# Processing Record 11 of Set 13 | jyvaskyla
# Processing Record 12 of Set 13 | korla
# Processing Record 13 of Set 13 | chahal
# Processing Record 14 of Set 13 | camacha
# Processing Record 15 of Set 13 | ust-koksa
# Processing Record 16 of Set 13 | kavaratti
# Processing Record 17 of Set 13 | koslan
# Processing Record 18 of Set 13 | nampula
# Processing Record 19 of Set 13 | salym
# Processing Record 20 of Set 13 | lalsk
# Processing Record 21 of Set 13 | panaba
# Processing Record 22 of Set 13 | kirovskiy
# Processing Record 23 of Set 13 | loreto
# Processing Record 24 of Set 13 | omboue
# Processing Record 25 of Set 13 | ajmer
# Processing Record 26 of Set 13 | xian
# Processing Record 27 of Set 13 | belaya gora
# Processing Record 28 of Set 13 | acari
# Processing Record 29 of Set 13 | yurimaguas
# Processing Record 30 of Set 13 | riyadh
# Processing Record 31 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 13 | idah
# Processing Record 33 of Set 13 | qinggang
# Processing Record 34 of Set 13 | christchurch
# Processing Record 35 of Set 13 | gat
# Processing Record 36 of Set 13 | hashtgerd
# Processing Record 37 of Set 13 | nicholasville
# Processing Record 38 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 13 | carballo
# Processing Record 40 of Set 13 | deputatskiy
# Processing Record 41 of Set 13 | nerchinskiy zavod
# Processing Record 42 of Set 13 | srostki
# Processing Record 43 of Set 13 | mpika
# Processing Record 44 of Set 13 | dolores
# Processing Record 45 of Set 13 | doume
# Processing Record 46 of Set 13 | saint-pierre
# Processing Record 47 of Set 13 | rockingham
# Processing Record 48 of Set 13 | curuca
# Processing Record 49 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 13 | arcata
# Processing Record 1 of Set 14 | byron bay
# Processing Record 2 of Set 14 | muzhi
# Processing Record 3 of Set 14 | goderich
# Processing Record 4 of Set 14 | celestun
# Processing Record 5 of Set 14 | rio claro
# Processing Record 6 of Set 14 | north bend
# Processing Record 7 of Set 14 | naspur
# Processing Record 8 of Set 14 | fredericton
# Processing Record 9 of Set 14 | nioki
# Processing Record 10 of Set 14 | gigmoto
# Processing Record 11 of Set 14 | viljoenskroon
# Processing Record 12 of Set 14 | bereznik
# Processing Record 13 of Set 14 | ghanzi
# Processing Record 14 of Set 14 | chimoio
# Processing Record 15 of Set 14 | catuday
# Processing Record 16 of Set 14 | bani walid
# Processing Record 17 of Set 14 | oshakati
# Processing Record 18 of Set 14 | ouargaye
# Processing Record 19 of Set 14 | coos bay
# Processing Record 20 of Set 14 | teguldet
# Processing Record 21 of Set 14 | joaima
# Processing Record 22 of Set 14 | zilair
# Processing Record 23 of Set 14 | sovetskiy
# Processing Record 24 of Set 14 | barmer
# Processing Record 25 of Set 14 | hirara
# Processing Record 26 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 14 | biak
# Processing Record 28 of Set 14 | progreso
# Processing Record 29 of Set 14 | broome
# Processing Record 30 of Set 14 | knysna
# Processing Record 31 of Set 14 | mbanza-ngungu
# Processing Record 32 of Set 14 | nigran
# Processing Record 33 of Set 14 | nyuksenitsa
# Processing Record 34 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 14 | bursol
# City not found. Skipping...
# Processing Record 36 of Set 14 | turbat
# Processing Record 37 of Set 14 | orbetello
# Processing Record 38 of Set 14 | miri
# Processing Record 39 of Set 14 | verkhnevilyuysk
# Processing Record 40 of Set 14 | road town
# Processing Record 41 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 14 | faya
# Processing Record 43 of Set 14 | sobolevo
# Processing Record 44 of Set 14 | seredka
# Processing Record 45 of Set 14 | kutum
# Processing Record 46 of Set 14 | secovce
# Processing Record 47 of Set 14 | berbera
# Processing Record 48 of Set 14 | yulara
# Processing Record 49 of Set 14 | fukue
# Processing Record 50 of Set 14 | sao joaquim de bicas
# Processing Record 1 of Set 15 | sebinkarahisar
# Processing Record 2 of Set 15 | sulangan
# Processing Record 3 of Set 15 | roma
# Processing Record 4 of Set 15 | quattro castella
# Processing Record 5 of Set 15 | ahipara
# Processing Record 6 of Set 15 | tirat karmel
# Processing Record 7 of Set 15 | san vicente
# Processing Record 8 of Set 15 | poum
# Processing Record 9 of Set 15 | paka
# Processing Record 10 of Set 15 | bac lieu
# Processing Record 11 of Set 15 | ostrovnoy
# Processing Record 12 of Set 15 | luorong
# Processing Record 13 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 15 | bukama
# Processing Record 15 of Set 15 | atagay
# Processing Record 16 of Set 15 | wewak
# Processing Record 17 of Set 15 | maltahohe
# Processing Record 18 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 15 | verkhovazhye
# Processing Record 20 of Set 15 | seydi
# Processing Record 21 of Set 15 | zhanakorgan
# Processing Record 22 of Set 15 | lehigh acres
# Processing Record 23 of Set 15 | bayeux
# Processing Record 24 of Set 15 | batemans bay
# Processing Record 25 of Set 15 | hawalli
# Processing Record 26 of Set 15 | valparaiso
# Processing Record 27 of Set 15 | cimarron hills
# Processing Record 28 of Set 15 | guerrero negro
# Processing Record 29 of Set 15 | tocopilla
# Processing Record 30 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 15 | along
# Processing Record 32 of Set 15 | garissa
# Processing Record 33 of Set 15 | kabinda
# Processing Record 34 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 15 | baley
# Processing Record 36 of Set 15 | marzuq
# Processing Record 37 of Set 15 | banff
# Processing Record 38 of Set 15 | ciudad del maiz
# Processing Record 39 of Set 15 | puerto madero
# Processing Record 40 of Set 15 | imeni poliny osipenko
# Processing Record 41 of Set 15 | qiongshan
# Processing Record 42 of Set 15 | kailasahar
# City not found. Skipping...
# Processing Record 43 of Set 15 | khingansk
# Processing Record 44 of Set 15 | sao jose da coroa grande
# Processing Record 45 of Set 15 | hanover park
# Processing Record 46 of Set 15 | banjar
# Processing Record 47 of Set 15 | qui nhon
# Processing Record 48 of Set 15 | da-an
# City not found. Skipping...
# Processing Record 49 of Set 15 | nhulunbuy
# Processing Record 50 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 16 | limbang
# Processing Record 2 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 16 | patratu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check that the product is a list of dictionaries
#city_data

# %% [markdown]
# # Convert results into a data frame

# %%
cities_df = pd.DataFrame(city_data)
cities_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Glenwood Springs      US  39.5505 -107.3248     50.81        73
# 1         Gladstone      AU -23.8500  151.2500     66.13        72
# 2           Ushuaia      AR -54.8000  -68.3000     45.57        95
# 3             Vaini      TO -21.2000 -175.2000     77.16        94
# 4          Saldanha      ZA -33.0117   17.9442     73.45        78
# 5          Khatanga      RU  71.9667  102.5000      9.55        95
# 6              Sola      VU -13.8833  167.5500     81.18        73
# 7          Lorengau      PG  -2.0226  147.2712     81.09        81
# 8             Airai      TL  -8.9266  125.4092     60.48        91
# 9            Barrow      US  71.2906 -156.7887     -5.78        84
#
#    Cloudiness  Wind Speed       Description
# 0         100       11.50   overcast clouds
# 1           3        4.61         clear sky
# 2         100        9.10   overcast clouds
# 3          40        4.61  scattered clouds
# 4           2       12.26         clear sky
# 5          99       11.54   overcast clouds
# 6          87        4.03   overcast clouds
# 7          62        4.94     broken clouds
# 8         100        1.90   overcast clouds
# 9           0       18.41         clear sky

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'
cities_df.to_csv(output_data_file,index_label='City_ID')

# %%
#AIzaSyDaT9ERCZYnrJHRdY6AFwiWJlD--iu8BIk
